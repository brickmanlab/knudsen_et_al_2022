# %%
from Module_20220302 import *

# %%
table_2_50 = pd.DataFrame(np.loadtxt('2_det_tri_table_ics_[0.1, 5]_nics_50_tmax50.txt'), columns = ['FGF','Gss_tmax50','Nss_tmax50', 'Ess_tmax50', 'Gic', 'Nic', 'Eic'])
table_2_2 = pd.DataFrame(np.loadtxt('2_det_tri_table_ics_[0.1, 5]_nics_50_tmax2.txt'), columns = ['FGF','Gss_tmax2','Nss_tmax2', 'Ess_tmax2', 'Gic', 'Nic', 'Eic'])
table_2_1 = pd.DataFrame(np.loadtxt('2_det_tri_table_ics_[0.1, 5]_nics_50_tmax1.txt'), columns = ['FGF','Gss_tmax1','Nss_tmax1', 'Ess_tmax1', 'Gic', 'Nic', 'Eic'])
table_2_05 = pd.DataFrame(np.loadtxt('2_det_tri_table_ics_[0.1, 5]_nics_50_tmax0.5.txt'), columns = ['FGF','Gss_tmax05','Nss_tmax05', 'Ess_tmax05', 'Gic', 'Nic', 'Eic'])

table_3_50 = pd.DataFrame(np.loadtxt('3_det_tri_table_ics_[0.1, 5]_nics_50_tmax50.txt'), columns = ['FGF','Gss_tmax50','Nss_tmax50', 'Ess_tmax50', 'Gic', 'Nic', 'Eic'])
table_3_2 = pd.DataFrame(np.loadtxt('3_det_tri_table_ics_[0.1, 5]_nics_50_tmax2.txt'), columns = ['FGF','Gss_tmax2','Nss_tmax2', 'Ess_tmax2', 'Gic', 'Nic', 'Eic'])
table_3_1 = pd.DataFrame(np.loadtxt('3_det_tri_table_ics_[0.1, 5]_nics_50_tmax1.txt'), columns = ['FGF','Gss_tmax1','Nss_tmax1', 'Ess_tmax1', 'Gic', 'Nic', 'Eic'])
table_3_05 = pd.DataFrame(np.loadtxt('3_det_tri_table_ics_[0.1, 5]_nics_50_tmax0.5.txt'), columns = ['FGF','Gss_tmax05','Nss_tmax05', 'Ess_tmax05', 'Gic', 'Nic', 'Eic'])

# %%
#with tmax = 50 as highest
table_2 = pd.concat([table_2_05[["FGF", "Gic", "Nic","Eic","Gss_tmax05","Nss_tmax05","Ess_tmax05"]],table_2_1[["Gss_tmax1","Nss_tmax1","Ess_tmax1"]],table_2_2[["Gss_tmax2","Nss_tmax2","Ess_tmax2"]],table_2_50[["Gss_tmax50","Nss_tmax50","Ess_tmax50"]]],axis=1)
table_2_Gata6 = table_2.loc[(table_2['Gss_tmax50'] > 10)]
table_2_Nanog = table_2.loc[(table_2['Nss_tmax50'] > 7.5)]

table_3 = pd.concat([table_3_05[["FGF", "Gic", "Nic","Eic","Gss_tmax05","Nss_tmax05","Ess_tmax05"]],table_3_1[["Gss_tmax1","Nss_tmax1","Ess_tmax1"]],table_3_2[["Gss_tmax2","Nss_tmax2","Ess_tmax2"]],table_3_50[["Gss_tmax50","Nss_tmax50","Ess_tmax50"]]],axis=1)
table_3_Gata6 = table_3.loc[(table_3['Gss_tmax50'] > 10)]
table_3_Nanog = table_3.loc[(table_3['Nss_tmax50'] > 7.5)]

table_2_Gata6_85 = table_2_Gata6.loc[(table_2_Gata6['FGF'] == 0.85)]
table_2_Nanog_85 = table_2_Nanog.loc[(table_2_Nanog['FGF'] == 0.85)]

table_3_Gata6_85 = table_3_Gata6.loc[(table_3_Gata6['FGF'] == 0.85)]
table_3_Nanog_85 = table_3_Nanog.loc[(table_3_Nanog['FGF'] == 0.85)]

table_2_85 = table_2.loc[(table_2['FGF'] == 0.85)]
table_3_85 = table_3.loc[(table_3['FGF'] == 0.85)]

# %%
print(np.shape(table_2_85))
print(np.shape(table_3_85))
print(np.shape(table_2_Nanog_85))
print(np.shape(table_3_Nanog_85))
print(np.shape(table_2_Gata6_85))
print(np.shape(table_3_Gata6_85))
# Out:
# (2197, 16)
# (2197, 16)
# (1223, 16)
# (1244, 16)
# (974, 16)
# (953, 16)

# %%
table_3_Gata6_85
# Out:
#        FGF       Gic       Nic        Eic  Gss_tmax05  Nss_tmax05  Ess_tmax05  \
# 72    0.85  0.305788  0.100000   0.992539    3.613597    3.207461    3.690594
# 77    0.85  0.331202  0.100000   0.992539    3.753173    3.173483    3.688492
# 82    0.85  0.358728  0.100000   0.992539    3.901389    3.133751    3.685705
# 87    0.85  0.388543  0.100000   0.992539    4.057497    3.087896    3.682016
# 92    0.85  0.420835  0.100000   0.992539    4.220458    3.035777    3.677152
# ...    ...       ...       ...        ...         ...         ...         ...
# 9267  0.85  2.437330  2.077632  11.781488    5.527800    4.131349   12.167403
# 9272  0.85  2.639898  2.077632  11.781488    5.759966    3.994515   12.162318
# 9277  0.85  2.859302  2.077632  11.781488    6.012542    3.850401   12.155937
# 9482  0.85  2.437330  2.250305  12.087463    5.316141    4.316446   12.370449
# 9487  0.85  2.639898  2.250305  12.087463    5.548917    4.174752   12.366367
#
# ...

# %%
table_2_Gata6_85
# Out:
#        FGF       Gic       Nic  Eic  Gss_tmax05  Nss_tmax05  Ess_tmax05  \
# 82    0.85  0.358728  0.100000  0.0    1.321043    1.474419         0.0
# 87    0.85  0.388543  0.100000  0.0    1.688157    1.472370         0.0
# 92    0.85  0.420835  0.100000  0.0    2.152889    1.466578         0.0
# 97    0.85  0.455810  0.100000  0.0    2.661905    1.452634         0.0
# 102   0.85  0.493693  0.100000  0.0    3.176075    1.425913         0.0
# ...    ...       ...       ...  ...         ...         ...         ...
# 9272  0.85  2.639898  2.077632  0.0    5.843516    3.901632         0.0
# 9277  0.85  2.859302  2.077632  0.0    6.099706    3.757779         0.0
# 9477  0.85  2.250305  2.250305  0.0    5.147724    4.383025         0.0
# 9482  0.85  2.437330  2.250305  0.0    5.370514    4.245760         0.0
# 9487  0.85  2.639898  2.250305  0.0    5.611718    4.100969         0.0
#
#       Gss_tmax1  Nss_tmax1  Ess_tmax1  Gss_tmax2  Nss_tmax2  Ess_tmax2  \
# ...

# %%
rows3 = list(table_3_Gata6_85.index)
rows2 = list(table_2_Gata6_85.index)
rows3_set = set(rows3)
intersection = rows3_set.intersection(rows2)
rows = list(intersection)

table_2_Gata6_85_fil = table_2_Gata6_85.loc[table_2_Gata6_85.index.isin(rows)]
table_3_Gata6_85_fil = table_3_Gata6_85.loc[table_3_Gata6_85.index.isin(rows)]

print(np.shape(table_2_Gata6_85_fil))
np.shape(table_3_Gata6_85_fil)
# Out:
# (941, 16)
# (941, 16)

# %%
rows3 = list(table_3_Nanog_85.index)
rows2 = list(table_2_Nanog_85.index)
rows3_set = set(rows3)
intersection = rows3_set.intersection(rows2)
rows = list(intersection)

table_2_Nanog_85_fil = table_2_Nanog_85.loc[table_2_Nanog_85.index.isin(rows)]
table_3_Nanog_85_fil = table_3_Nanog_85.loc[table_3_Nanog_85.index.isin(rows)]

print(np.shape(table_2_Nanog_85_fil))
np.shape(table_3_Nanog_85_fil)
# Out:
# (1211, 16)
# (1211, 16)

# %%
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

Reds = cm.get_cmap('Reds', 256)
Reds_new = Reds(np.linspace(0, 1, 256))
white = np.array([256/256, 256/256, 256/256, 1])
Reds_new[:1, :] = white
Reds_t = ListedColormap(Reds_new)

Greens = cm.get_cmap('Greens', 256)
Greens_new = Greens(np.linspace(0, 1, 256))
white = np.array([256/256, 256/256, 256/256, 1])
Greens_new[:1, :] = white
Greens_t = ListedColormap(Greens_new)

# %%
plt.figure()
#plt.plot(ic_inrange[:,0], ic_inrange[:,1], '*', alpha = 0.1)
x_min = 0.01
x_max = 20
reso = 100
x_bins = np.logspace(lin_to_log(x_min),lin_to_log(x_max), base=2, num=reso)
y_bins = x_bins
#print(x_bins)

G_Nanog_ic = table_3_Gata6_85_fil["Nic"]
G_Gata_ic = table_3_Gata6_85_fil["Gic"]
N_Nanog_ic = table_3_Nanog_85_fil["Nic"]
N_Gata_ic = table_3_Nanog_85_fil["Gic"]
plt.hist2d(G_Gata_ic, G_Nanog_ic, bins = [x_bins, y_bins], cmap = Reds_t, alpha = 1)
plt.hist2d(N_Gata_ic, N_Nanog_ic, bins = [x_bins, y_bins], cmap = Greens_t, alpha = 0.25)
plt.xlim(0,16)
plt.ylim(0,16)
plt.xlabel('Gata6 IC')
plt.ylabel('Nanog IC')
plt.colorbar()
plt.savefig('GNFE_ICs_tnoise_0.svg')
plt.show()

G_Nanog_ic = table_3_Gata6_85_fil["Nss_tmax05"]
G_Gata_ic = table_3_Gata6_85_fil["Gss_tmax05"]
N_Nanog_ic = table_3_Nanog_85_fil["Nss_tmax05"]
N_Gata_ic = table_3_Nanog_85_fil["Gss_tmax05"]
plt.hist2d(G_Gata_ic, G_Nanog_ic, bins = [x_bins, y_bins], cmap = Reds_t, alpha = 1, vmax = 20)
plt.hist2d(N_Gata_ic, N_Nanog_ic, bins = [x_bins, y_bins], cmap = Greens_t, alpha = 0.4, vmax = 20)
plt.xlim(0,16)
plt.ylim(0,16)
plt.xlabel('Gata6 IC')
plt.ylabel('Nanog IC')
plt.colorbar()
plt.savefig('GNFE_ICs_tnoise_1.svg')
plt.show()

G_Nanog_ic = table_3_Gata6_85_fil["Nss_tmax1"]
G_Gata_ic = table_3_Gata6_85_fil["Gss_tmax1"]
N_Nanog_ic = table_3_Nanog_85_fil["Nss_tmax1"]
N_Gata_ic = table_3_Nanog_85_fil["Gss_tmax1"]
plt.hist2d(G_Gata_ic, G_Nanog_ic, bins = [x_bins, y_bins], cmap = Reds_t, alpha = 1, vmax = 20)
plt.hist2d(N_Gata_ic, N_Nanog_ic, bins = [x_bins, y_bins], cmap = Greens_t, alpha = 0.4, vmax = 20)
plt.xlim(0,16)
plt.ylim(0,16)
plt.xlabel('Gata6 IC')
plt.ylabel('Nanog IC')
plt.colorbar()
plt.savefig('GNFE_ICs_tnoise_2.svg')
plt.show()

G_Nanog_ic = table_3_Gata6_85_fil["Nss_tmax2"]
G_Gata_ic = table_3_Gata6_85_fil["Gss_tmax2"]
N_Nanog_ic = table_3_Nanog_85_fil["Nss_tmax2"]
N_Gata_ic = table_3_Nanog_85_fil["Gss_tmax2"]
plt.hist2d(G_Gata_ic, G_Nanog_ic, bins = [x_bins, y_bins], cmap = Reds_t, alpha = 1, vmax = 20)
plt.hist2d(N_Gata_ic, N_Nanog_ic, bins = [x_bins, y_bins], cmap = Greens_t, alpha = 0.4, vmax = 20)
plt.xlim(0,16)
plt.ylim(0,16)
plt.xlabel('Gata6 IC')
plt.ylabel('Nanog IC')
plt.colorbar()
plt.savefig('GNFE_ICs_tnoise_3.svg')
plt.show()

G_Nanog_ic = table_3_Gata6_85_fil["Nss_tmax50"]
G_Gata_ic = table_3_Gata6_85_fil["Gss_tmax50"]
N_Nanog_ic = table_3_Nanog_85_fil["Nss_tmax50"]
N_Gata_ic = table_3_Nanog_85_fil["Gss_tmax50"]
plt.hist2d(G_Gata_ic, G_Nanog_ic, bins = [x_bins, y_bins], cmap = Reds_t, alpha = 1, vmax = 20)
plt.hist2d(N_Gata_ic, N_Nanog_ic, bins = [x_bins, y_bins], cmap = Greens_t, alpha = 0.5, vmax = 20)
plt.xlim(0,16)
plt.ylim(0,16)
plt.xlabel('Gata6 IC')
plt.ylabel('Nanog IC')
plt.colorbar()
plt.savefig('GNFE_ICs_tnoise_SFP.svg')
plt.show()

G_Nanog_ic = table_3_Gata6_85_fil["Nic"]
G_Gata_ic = table_3_Gata6_85_fil["Gic"]
N_Nanog_ic = table_3_Nanog_85_fil["Nic"]
N_Gata_ic = table_3_Nanog_85_fil["Gic"]
#plt.hist2d(G_Gata_ic, G_Nanog_ic, bins = [x_bins, y_bins], cmap = Reds_t, alpha = 0.5, vmax = 1)
plt.hist2d(N_Gata_ic, N_Nanog_ic, bins = [x_bins, y_bins], cmap = Greens_t, alpha = 0.5, vmax = 1)
plt.xlim(0,16)
plt.ylim(0,16)
plt.xlabel('Gata6 IC')
plt.ylabel('Nanog IC')
plt.colorbar()
#plt.savefig('colorbar_1_green.svg')
plt.show()

# %%
plt.figure()
#plt.plot(ic_inrange[:,0], ic_inrange[:,1], '*', alpha = 0.1)
x_min = 0.01
x_max = 20
reso = 100
x_bins = np.logspace(lin_to_log(x_min),lin_to_log(x_max), base=2, num=reso)
y_bins = x_bins
#print(x_bins)

G_Nanog_ic = table_2_Gata6_85_fil["Nic"]
G_Gata_ic = table_2_Gata6_85_fil["Gic"]
N_Nanog_ic = table_2_Nanog_85_fil["Nic"]
N_Gata_ic = table_2_Nanog_85_fil["Gic"]
plt.hist2d(G_Gata_ic, G_Nanog_ic, bins = [x_bins, y_bins], cmap = Reds_t, alpha = 1)
plt.hist2d(N_Gata_ic, N_Nanog_ic, bins = [x_bins, y_bins], cmap = Greens_t, alpha = 0.25)
plt.xlim(0,16)
plt.ylim(0,16)
plt.xlabel('Gata6 IC')
plt.ylabel('Nanog IC')
plt.colorbar()
plt.savefig('GNF_ICs_tnoise_0.svg')
plt.show()

G_Nanog_ic = table_2_Gata6_85_fil["Nss_tmax05"]
G_Gata_ic = table_2_Gata6_85_fil["Gss_tmax05"]
N_Nanog_ic = table_2_Nanog_85_fil["Nss_tmax05"]
N_Gata_ic = table_2_Nanog_85_fil["Gss_tmax05"]
plt.hist2d(G_Gata_ic, G_Nanog_ic, bins = [x_bins, y_bins], cmap = Reds_t, alpha = 1, vmax = 20)
plt.hist2d(N_Gata_ic, N_Nanog_ic, bins = [x_bins, y_bins], cmap = Greens_t, alpha = 0.4, vmax = 20)
plt.xlim(0,16)
plt.ylim(0,16)
plt.xlabel('Gata6 IC')
plt.ylabel('Nanog IC')
plt.colorbar()
plt.savefig('GNF_ICs_tnoise_1.svg')
plt.show()

G_Nanog_ic = table_2_Gata6_85_fil["Nss_tmax1"]
G_Gata_ic = table_2_Gata6_85_fil["Gss_tmax1"]
N_Nanog_ic = table_2_Nanog_85_fil["Nss_tmax1"]
N_Gata_ic = table_2_Nanog_85_fil["Gss_tmax1"]
plt.hist2d(G_Gata_ic, G_Nanog_ic, bins = [x_bins, y_bins], cmap = Reds_t, alpha = 1, vmax = 20)
plt.hist2d(N_Gata_ic, N_Nanog_ic, bins = [x_bins, y_bins], cmap = Greens_t, alpha = 0.4, vmax = 20)
plt.xlim(0,16)
plt.ylim(0,16)
plt.xlabel('Gata6 IC')
plt.ylabel('Nanog IC')
plt.colorbar()
plt.savefig('GNF_ICs_tnoise_2.svg')
plt.show()

G_Nanog_ic = table_2_Gata6_85_fil["Nss_tmax2"]
G_Gata_ic = table_2_Gata6_85_fil["Gss_tmax2"]
N_Nanog_ic = table_2_Nanog_85_fil["Nss_tmax2"]
N_Gata_ic = table_2_Nanog_85_fil["Gss_tmax2"]
plt.hist2d(G_Gata_ic, G_Nanog_ic, bins = [x_bins, y_bins], cmap = Reds_t, alpha = 1, vmax = 20)
plt.hist2d(N_Gata_ic, N_Nanog_ic, bins = [x_bins, y_bins], cmap = Greens_t, alpha = 0.4, vmax = 20)
plt.xlim(0,16)
plt.ylim(0,16)
plt.xlabel('Gata6 IC')
plt.ylabel('Nanog IC')
plt.colorbar()
plt.savefig('GNF_ICs_tnoise_3.svg')
plt.show()

G_Nanog_ic = table_2_Gata6_85_fil["Nss_tmax50"]
G_Gata_ic = table_2_Gata6_85_fil["Gss_tmax50"]
N_Nanog_ic = table_2_Nanog_85_fil["Nss_tmax50"]
N_Gata_ic = table_2_Nanog_85_fil["Gss_tmax50"]
plt.hist2d(G_Gata_ic, G_Nanog_ic, bins = [x_bins, y_bins], cmap = Reds_t, alpha = 1, vmax = 20)
plt.hist2d(N_Gata_ic, N_Nanog_ic, bins = [x_bins, y_bins], cmap = Greens_t, alpha = 0.5, vmax = 20)
plt.xlim(0,16)
plt.ylim(0,16)
plt.xlabel('Gata6 IC')
plt.ylabel('Nanog IC')
plt.colorbar()
plt.savefig('GNF_ICs_tnoise_SFP.svg')
plt.show()

# %%
table_2_Gata6_85_fil
# Out:
#        FGF       Gic       Nic  Eic  Gss_tmax05  Nss_tmax05  Ess_tmax05  \
# 82    0.85  0.358728  0.100000  0.0    1.321043    1.474419         0.0
# 87    0.85  0.388543  0.100000  0.0    1.688157    1.472370         0.0
# 92    0.85  0.420835  0.100000  0.0    2.152889    1.466578         0.0
# 97    0.85  0.455810  0.100000  0.0    2.661905    1.452634         0.0
# 102   0.85  0.493693  0.100000  0.0    3.176075    1.425913         0.0
# ...    ...       ...       ...  ...         ...         ...         ...
# 9267  0.85  2.437330  2.077632  0.0    5.604094    4.040460         0.0
# 9272  0.85  2.639898  2.077632  0.0    5.843516    3.901632         0.0
# 9277  0.85  2.859302  2.077632  0.0    6.099706    3.757779         0.0
# 9482  0.85  2.437330  2.250305  0.0    5.370514    4.245760         0.0
# 9487  0.85  2.639898  2.250305  0.0    5.611718    4.100969         0.0
#
#       Gss_tmax1  Nss_tmax1  Ess_tmax1  Gss_tmax2  Nss_tmax2  Ess_tmax2  \
# ...

# %%
table_3_Gata6_85_fil
# Out:
#        FGF       Gic       Nic        Eic  Gss_tmax05  Nss_tmax05  Ess_tmax05  \
# 82    0.85  0.358728  0.100000   0.992539    3.901389    3.133751    3.685705
# 87    0.85  0.388543  0.100000   0.992539    4.057497    3.087896    3.682016
# 92    0.85  0.420835  0.100000   0.992539    4.220458    3.035777    3.677152
# 97    0.85  0.455810  0.100000   0.992539    4.388956    2.977536    3.670783
# 102   0.85  0.493693  0.100000   0.992539    4.561439    2.913632    3.662527
# ...    ...       ...       ...        ...         ...         ...         ...
# 9267  0.85  2.437330  2.077632  11.781488    5.527800    4.131349   12.167403
# 9272  0.85  2.639898  2.077632  11.781488    5.759966    3.994515   12.162318
# 9277  0.85  2.859302  2.077632  11.781488    6.012542    3.850401   12.155937
# 9482  0.85  2.437330  2.250305  12.087463    5.316141    4.316446   12.370449
# 9487  0.85  2.639898  2.250305  12.087463    5.548917    4.174752   12.366367
#
# ...

# %%
np.savetxt('../FIG-H_SFIG_C/table_node2_max50_FGF85_Gata6ICs_20220420.txt', table_2_Gata6_85_fil)
np.savetxt('../FIG-H_SFIG_C/table_node2_max50_FGF85_NanogICs_20220420.txt', table_2_Nanog_85_fil)
np.savetxt('../FIG-H_SFIG_C/table_node3_max50_FGF85_Gata6ICs_20220420.txt', table_3_Gata6_85_fil)
np.savetxt('../FIG-H_SFIG_C/table_node3_max50_FGF85_NanogICs_20220420.txt', table_3_Nanog_85_fil)
