# %%
from Module_20220302 import *

# %% [markdown]
# ## Streamplots and paths

# %%
parameters['FGF'] = 0.85

# %%
min_var = 0
max_var = 17
var_step = 1 #specify in module
E_slice = 5

make_streamplot(equations_NG_and_F,min_var, max_var, var_step, E_slice = E_slice, file_label = 2)
make_streamplot(equations_NGE_and_F,min_var, max_var, var_step, E_slice = E_slice, file_label = 3)
# Out:
# (2, 17, 17)
# derivs_g shape= (2, 17, 17)
# (2, 17, 17)
# derivs_g shape= (2, 17, 17)

# %% [markdown]
# ### NANOG trajectories:

# %%
plot=True
parameters['FGF'] = 0.85
x = 0.5
y = 1
z = find_ss_E(x, y, parameters)

ic = [x, y, z] #initial conditions
traj_NGFE = sample_trajectories(ic,parameters,equations_NGE_and_F, verbose = plot, file_label = "3N") #, tmax_int = 50, tmax_ss = 500
traj_NGF = sample_trajectories(ic,parameters,equations_NG_and_F, verbose = plot, file_label = "2N") # tmax_int = 50, tmax_ss = 500,

# %% [markdown]
# ### GATA6 trajectories:

# %%
plot=True
parameters['FGF'] = 0.85
x = 1
y = 0.5
z = find_ss_E(x, y, parameters)

ic = [x, y, z] #initial conditions
traj_NGFE = sample_trajectories(ic,parameters,equations_NGE_and_F, verbose = plot, file_label = "3G") #, tmax_int = 50, tmax_ss = 500
traj_NGF = sample_trajectories(ic,parameters,equations_NG_and_F, verbose = plot, file_label = "2G") # tmax_int = 50, tmax_ss = 500,
